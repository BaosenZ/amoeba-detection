# %% [markdown]
# # Solution: Amoeba Classification

# %% [markdown]
# This is the solution for amoeba classification assignment.
#
# Here, we use the images that are collected from our lab to train our own custom model to classify the images if they contain amoeba or not.

# %% [markdown]
# ## Table of content
#
# * Load images dataset
# * Data preparation
# * Build and train the model
# * Evaluate the model
# * Inference

# %% [markdown]
# # Load images dataset

# %% [markdown]
# The images dataset is loaded and we will use them to train our custom model. All of the images are collected in our lab.

# %%
# upload zip file of the dataset from local
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))

# !unzip dataset-amoebaClassification.zip
# Out:
#      <input type="file" id="files-b215e4f6-963c-4372-9969-168273d987b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b215e4f6-963c-4372-9969-168273d987b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset-amoebaClassification.zip to dataset-amoebaClassification.zip
# User uploaded file "dataset-amoebaClassification.zip" with length 11471309 bytes
# Archive:  dataset-amoebaClassification.zip
#    creating: dataset-amoebaClassification/test/
#    creating: dataset-amoebaClassification/test/amoeba/
#   inflating: dataset-amoebaClassification/test/amoeba/a10.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a100.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a100copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a10copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a11.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a11copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a6.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a6copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a7.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a7copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a8.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a8copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a9.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a91.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a91copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a92.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a92copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a93.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a93copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a94.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a94copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a95.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a95copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a96.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a96copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a97.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a97copy.jpg
#   inflating: dataset-amoebaClassification/test/amoeba/a9copy.jpg
#    creating: dataset-amoebaClassification/test/noAmoeba/
#   inflating: dataset-amoebaClassification/test/noAmoeba/17.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/18.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/19.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/20.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/21.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/22.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/23.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/24.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/25.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/323.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/323copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/324.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/324copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/325.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/325copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/326.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/326copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/327.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/327copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/328.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/328copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/329.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/329copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/330.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/330copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/331.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/331copy.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/332.jpg
#   inflating: dataset-amoebaClassification/test/noAmoeba/332copy.jpg
#    creating: dataset-amoebaClassification/train/
#    creating: dataset-amoebaClassification/train/amoeba/
#   inflating: dataset-amoebaClassification/train/amoeba/a1.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a108.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a108copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a113.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a113copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a12.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a12copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a13.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a13copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a14.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a14copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a15.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a15copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a16.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a16copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a17.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a17copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a18.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a18copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a19.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a19copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a1copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a20.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a20copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a21.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a21copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a22.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a22copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a23.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a23copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a24.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a24copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a25.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a25copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a26.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a26copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a27.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a27copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a28.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a28copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a29.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a29copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a30.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a30copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a31.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a31copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a32.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a32copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a33.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a33copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a34.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a34copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a35.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a35copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a36.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a36copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a37.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a37copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a38.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a38copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a39.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a39copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a40.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a40copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a41.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a41copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a42.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a42copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a43.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a43copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a44.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a44copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a45.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a45copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a46.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a46copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a47.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a47copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a48.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a48copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a49.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a49copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a50.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a50copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a51.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a51copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a52.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a52copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a53.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a53copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a54.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a54copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a55.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a55copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a56.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a56copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a57.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a57copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a58.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a58copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a59.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a59copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a60.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a60copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a61.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a61copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a62.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a62copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a63.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a63copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a64.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a64copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a65.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a65copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a66.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a66copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a67.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a67copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a68.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a68copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a69.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a69copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a70.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a70copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a71.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a71copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a72.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a72copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a73.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a73copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a74.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a74copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a75.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a75copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a76.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a76copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a77.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a77copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a78.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a78copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a79.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a79copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a80.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a80copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a81.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a81copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a82.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a82copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a83.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a83copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a84.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a84copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a85.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a85copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a86.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a86copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a87.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a87copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a88.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a88copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a89.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a89copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a90.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a90copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a98.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a98copy.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a99.jpg
#   inflating: dataset-amoebaClassification/train/amoeba/a99copy.jpg
#    creating: dataset-amoebaClassification/train/noAmoeba/
#   inflating: dataset-amoebaClassification/train/noAmoeba/102.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/102copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/103.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/103copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/104.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/104copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/105.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/105copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/106.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/106copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/107.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/107copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/108.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/108copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/109.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/109copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/110.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/110copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/26.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/27.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/28.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/29.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/30.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/304.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/304copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/305.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/305copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/306.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/306copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/307.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/307copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/308.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/308copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/309.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/309copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/31.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/310.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/310copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/311.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/311copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/312.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/312copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/313.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/313copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/314.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/314copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/315.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/315copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/316.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/316copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/317.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/317copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/318.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/318copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/319.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/319copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/32.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/320.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/320copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/321.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/321copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/322.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/322copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/33.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/34.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/35.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/36.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/37.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/38.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/39.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/40.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/41.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/42.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/43.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/44.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/45.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/46.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/47.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/48.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/49.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/50.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/51.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/52.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/53.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/54.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/55.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/56.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/57.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/58.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/60.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/61.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/62.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/63.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/64.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/65.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/66.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/67.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/68.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/69.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/70.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/71.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/72.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/73.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/74.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/75.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/75copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/76.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/76copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/77.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/77copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/78.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/78copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/79.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/79copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/80.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/80copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/81.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/81copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/82.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/82copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/87.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/87copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/88.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/88copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/89.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/89copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/90.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/90copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/91.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/91copy.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/92.jpg
#   inflating: dataset-amoebaClassification/train/noAmoeba/92copy.jpg
#    creating: dataset-amoebaClassification/validation/
#    creating: dataset-amoebaClassification/validation/amoeba/
#   inflating: dataset-amoebaClassification/validation/amoeba/a101.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a101copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a102.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a102copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a103.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a103copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a104.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a104copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a105.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a105copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a106.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a106copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a107.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a107copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a109.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a109copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a110.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a110copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a111.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a111copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a112.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a112copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a114.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a114copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a2.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a2copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a3.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a3copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a4.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a4copy.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a5.jpg
#   inflating: dataset-amoebaClassification/validation/amoeba/a5copy.jpg
#    creating: dataset-amoebaClassification/validation/noAmoeba/
#   inflating: dataset-amoebaClassification/validation/noAmoeba/1.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/10.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/100.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/101.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/11.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/12.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/13.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/14.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/15.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/16.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/2.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/3.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/333.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/333copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/334.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/334copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/335.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/335copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/336.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/336copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/337.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/337copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/338.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/338copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/339.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/339copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/340.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/340copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/341.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/341copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/342.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/342copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/343.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/343copy.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/4.jpg
#   inflating: dataset-amoebaClassification/validation/noAmoeba/5.jpg

# %%
# download dataset from github

# %%shell
# git clone https://github.com/BaosenZ/amoeba-detection.git

# %% [markdown]
# # Data preparation

# %% [markdown]
# In this step, we will prepare dataset, including spliting training, validation and test dataset, and normalize dataset. We provide one method to prepare the dataset in here. More way to prepare the dataset can be found here: https://keras.io/examples/vision/image_classification_from_scratch/.

# %%
import os
import numpy as np
from tqdm import tqdm
from glob import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# training data preparation

# define image size, it can be modified 
img_size = 299
# training images dataset path
train_path = 'dataset-amoebaClassification/train' 
nub_train = len(glob(train_path + '/*/*.jpg'))
# Create empty array, fill out the image array to newly-created array. 
X_train = np.zeros((nub_train,img_size,img_size,3),dtype=np.uint8) 
y_train = np.zeros((nub_train,),dtype=np.uint8)

i = 0
for img_path in tqdm(glob(train_path + '/*/*.jpg')):
    # print(img_path)

    img = Image.open(img_path)
    # image resize
    img = img.resize((img_size,img_size)) 
    # images are converted to array
    arr = np.asarray(img)
    # assign array
    X_train[i, :, :, :] = arr
    
    if img_path.split('/')[-2] == 'amoeba':
        # Set amoeba class as 0
        y_train[i] = 0
    else:
        # Set no amoeba class as 1
        y_train[i] = 1
        
    i += 1
# Out:
# 100%|██████████| 300/300 [00:11<00:00, 25.49it/s]

# %%
# validation data preparation

# define image size, it can be modified 
img_size = 299
# validation images dataset path
validation_path = 'dataset-amoebaClassification/validation' 
nub_validation = len(glob(validation_path + '/*/*.jpg'))
# Creat empty array, fill out the image array to newly-created array. 
X_validation = np.zeros((nub_validation,img_size,img_size,3),dtype=np.uint8) 
y_validation = np.zeros((nub_validation,),dtype=np.uint8)

i = 0
for img_path in tqdm(glob(validation_path + '/*/*.jpg')):
    # print(img_path)

    img = Image.open(img_path)
    # image resize
    img = img.resize((img_size,img_size)) 
    # images are converted to array
    arr = np.asarray(img)
    # assign array
    X_validation[i, :, :, :] = arr
    
    if img_path.split('/')[-2] == 'amoeba':
        # Set cat class as 0
        y_validation[i] = 0
    else:
        # Set dog class as 1
        y_validation[i] = 1
        
    i += 1
# Out:
# 100%|██████████| 68/68 [00:02<00:00, 22.93it/s]

# %%
# test data preparation

img_size = 299
test_path = 'dataset-amoebaClassification/test'
nub_test = len(glob(test_path + '/*/*.jpg'))

X_test = np.zeros((nub_test,img_size,img_size,3),dtype=np.uint8) 
y_test = np.zeros((nub_test,),dtype=np.uint8)

i = 0
for img_path in tqdm(glob(test_path + '/*/*.jpg')):
    # print(img_path)

    img = Image.open(img_path)
    img = img.resize((img_size,img_size))
    arr = np.asarray(img)
    X_test[i, :, :, :] = arr
          
    if img_path.split('/')[-2] == 'amoeba':
        # Set cat class as 0
        y_test[i] = 0
    else:
        # Set dog class as 1
        y_test[i] = 1
        
    i += 1
# Out:
# 100%|██████████| 57/57 [00:02<00:00, 23.83it/s]

# %%
# Visualize the training dataset
fig,axes = plt.subplots(3,4,figsize=(20, 20))

j = 0
for i,img in enumerate(X_train[:12]):
    axes[i//4,j%4].imshow(img)
    j+=1

# %%
# normalize the dataset
X_mean = X_train.mean(axis=0, keepdims=True)
X_std = X_train.std(axis=0, keepdims=True) + 1e-7
X_train_norm = (X_train - X_mean) / X_std
X_validation_norm = (X_validation - X_mean) / X_std
X_test_norm = (X_test - X_mean) / X_std

X_train_norm = X_train_norm[..., np.newaxis]
X_validation_norm = X_validation_norm[..., np.newaxis]
X_test_norm = X_test_norm[..., np.newaxis]

# %% [markdown]
# # Build and train the model

# %% [markdown]
# Simple convolustional neural network (CNN) is used to train the model.

# %%
# Build the model (sequential CNN model)
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([                           
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[299, 299, 3]),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=32, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=2, activation='softmax'),
])

# %%
# Compile the model
model.compile(loss="sparse_categorical_crossentropy", optimizer="nadam", metrics=["accuracy"])

# %%
# Train the model
history = model.fit(X_train_norm, y_train, epochs=10, validation_data=(X_validation_norm, y_validation))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 414s 41s/step - loss: 2.9269 - accuracy: 0.6267 - val_loss: 0.4882 - val_accuracy: 1.0000
# Epoch 2/10
# 10/10 [==============================] - 408s 41s/step - loss: 0.5505 - accuracy: 0.8000 - val_loss: 0.3654 - val_accuracy: 0.9559
# Epoch 3/10
# 10/10 [==============================] - 408s 41s/step - loss: 0.5140 - accuracy: 0.7533 - val_loss: 0.3518 - val_accuracy: 0.9559
# Epoch 4/10
# 10/10 [==============================] - 420s 42s/step - loss: 0.5085 - accuracy: 0.8967 - val_loss: 0.3649 - val_accuracy: 0.9706
# Epoch 5/10
# 10/10 [==============================] - 423s 42s/step - loss: 0.4110 - accuracy: 0.9000 - val_loss: 0.3148 - val_accuracy: 0.9559
# Epoch 6/10
# 10/10 [==============================] - 412s 41s/step - loss: 0.3777 - accuracy: 0.9200 - val_loss: 0.3247 - val_accuracy: 0.9559
# Epoch 7/10
# 10/10 [==============================] - 408s 41s/step - loss: 0.4567 - accuracy: 0.9200 - val_loss: 0.2747 - val_accuracy: 1.0000
# Epoch 8/10
# 10/10 [==============================] - 414s 41s/step - loss: 0.3362 - accuracy: 0.9433 - val_loss: 0.2800 - val_accuracy: 1.0000
# Epoch 9/10
# 10/10 [==============================] - 411s 41s/step - loss: 0.3097 - accuracy: 0.9533 - val_loss: 0.2631 - val_accuracy: 1.0000
# Epoch 10/10
# 10/10 [==============================] - 411s 41s/step - loss: 0.2753 - accuracy: 0.9733 - val_loss: 0.2774 - val_accuracy: 0.9559

# %% [markdown]
# # Evaluate the model

# %%
# visualize the model structure with model.summary(). Feel free to comment out the code below to visualize the model structure

# model.summary()

# %% [markdown]
# The test dataset is not used for training and validation, which means they are new to the trained model. And we will use it to get the performance of the model. The performance is acceptable because the accuracy for test dataset is nearly the same with accuracy for train and validation dataset.

# %%
# Using test dataset to evaluate loss and accuracy for trained model
results = model.evaluate(X_test_norm, y_test, batch_size=128)
# Out:
# 1/1 [==============================] - 22s 22s/step - loss: 0.2592 - accuracy: 1.0000

# %% [markdown]
# At the end of epoch, the accuary for training and validation dataset should be close. This is a easy way to determine if there is overfitting or not.

# %%
# plot accuracy vs epoch
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left') 
plt.ylim([0, 1.1])
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# We visualize the image and use your judgement to see if there is amoeba exist in the image and then compare it with the model prediction.
# :

# %%
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np

# Visualize one image, X_test[x]. Here we choose X_test[1]. You can choose any of the images among all test dataset
img1 = X_test[1]
plt.imshow(img1)

# %% [markdown]
# we will predict the image above with model.predict() function to see if it matches with your judgement.

# %%
# class label
class_label = ['amoeba exist', 'no amoeba exist']

# image process
x = np.squeeze(X_test_norm[1])
x = image.img_to_array(x)
x = np.expand_dims(x, axis=0)

# predict the image with model.predict()
y_prob = model.predict(x)
print("probality for each of the catogaries: ", y_prob)
y_class = y_prob.argmax(axis=-1)
print("model predict: ", class_label[y_class[0]])
# Out:
# probality for each of the catogaries:  [[1.0000000e+00 3.6666708e-11]]
# model predict:  amoeba exist
