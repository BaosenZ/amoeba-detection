# %% [markdown]
# # Solution: Amoeba Classification

# %% [markdown]
# This is the solution for amoeba classification assignment.
#
# Here, we use the images that are collected from our lab to train our own custom model to classify the images if they contain amoeba or not. The dataset is not large enough, we use two techniques to make our experiment reproducible: data augmentation and repeat the experiment multiple times.

# %% [markdown]
# ## Table of content
#
# * Load images dataset
# * Data preparation
# * Build and train the model
# * Evaluate the model
# * Inference

# %% [markdown]
# # Load images dataset

# %% [markdown]
# The images dataset is loaded and we will use them to train our custom model. All of the images are collected in our lab.

# %%
# download dataset from github

# %%shell
git clone https://github.com/BaosenZ/amoeba-detection.git
# Out:
# Cloning into 'amoeba-detection'...
# remote: Enumerating objects: 2109, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 2109 (delta 13), reused 23 (delta 7), pack-reused 2075
# Receiving objects: 100% (2109/2109), 315.32 MiB | 26.81 MiB/s, done.
# Resolving deltas: 100% (338/338), done.
# Checking out files: 100% (3056/3056), done.

# %%
# copy the dataset from github folder to 'content' 
# !cp -r '/content/amoeba-detection/dataset-level1/dataset-amoebaClassification' '/content'

# %%
# upload zip file of the dataset from local

# from google.colab import files
# uploaded = files.upload()
# for fn in uploaded.keys():
#     print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))

# !unzip dataset-amoebaClassification.zip

# %% [markdown]
# # Data preparation

# %% [markdown]
# In this step, we will prepare dataset, including data augmentation, spliting training, validation and test dataset, and normalize dataset. More way to prepare the dataset can be found here: https://keras.io/api/data_loading/image/.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Data augmentation can obtain more data for training and validation. When the training dataset is small, we can do data augmentation to existing data and add those data to the training dataset. For image data specifically, data augmentation could consist of things like flipping the image horizontally or vertically, rotating the image, zooming in or out, cropping, or varying the color and so on.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, shear_range=0.15, zoom_range=0.1, 
    channel_shift_range=10., horizontal_flip=True)
    
# Data augmentation for train amoeba dataset
fileList=os.listdir("./dataset-amoebaClassification/train/amoeba/")

for i in fileList:
    image_path = 'dataset-amoebaClassification/train/amoeba/' + i
    image = np.expand_dims(plt.imread(image_path),0)
    aug_iter = gen.flow(image)
    aug_images = [next(aug_iter)[0].astype(np.uint8) for m in range(2)]

    for j in range(0,2):
        img = Image.fromarray(aug_images[j])
        save_path = './dataset-amoebaClassification/train/amoeba' + "/" + "aug-" + str(j) + str(i)
        img.save(save_path)

# The augmentation image will save into ./dataset-amoebaClassification/train/amoeba folder. Check this folder and find out\
# augmentation image with prefix 'aug-'.

# %%
# Data augmentation for train noAmoeba dataset
fileList2=os.listdir("./dataset-amoebaClassification/train/noAmoeba/")

for i2 in fileList2:
    image_path = 'dataset-amoebaClassification/train/noAmoeba/' + i2
    image = np.expand_dims(plt.imread(image_path),0)
    aug_iter = gen.flow(image)
    aug_images = [next(aug_iter)[0].astype(np.uint8) for m2 in range(2)]

    for j2 in range(0,2):
        img = Image.fromarray(aug_images[j2])
        save_path = './dataset-amoebaClassification/train/noAmoeba' + "/" + "aug-" + str(j2) + str(i2)
        img.save(save_path)

# The augmentation image will save into ./dataset-amoebaClassification/train/noAmoeba folder. Check this folder and find out\
# augmentation image with prefix 'aug-'.

# %% [markdown]
# ## Split and normalize the dataset

# %%
import os
import numpy as np
from tqdm import tqdm
from glob import glob
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras

# training data preparation

# define image size, it can be modified 
img_size = 150
# training images dataset path
train_path = 'dataset-amoebaClassification/train' 
nub_train = len(glob(train_path + '/*/*.jpg'))
# Create empty array, fill out the image array to newly-created array. 
X_train_full = np.zeros((nub_train,img_size,img_size,3),dtype=np.uint8) 
y_train_full = np.zeros((nub_train,),dtype=np.uint8)

i = 0
for img_path in tqdm(glob(train_path + '/*/*.jpg')):
    img = Image.open(img_path)
    # image resize
    img = img.resize((img_size,img_size)) 
    # images are converted to array
    arr = np.asarray(img)
    # assign array
    X_train_full[i, :, :, :] = arr
    
    if img_path.split('/')[-2] == 'amoeba':
        # Set amoeba class as 1
        y_train_full[i] = 1
    else:
        # Set no amoeba class as 0
        y_train_full[i] = 0
        
    i += 1
# Out:
# 100%|██████████| 1077/1077 [00:31<00:00, 33.85it/s]

# %%
# # test data preparation

img_size = 150
test_path = 'dataset-amoebaClassification/test'
nub_test = len(glob(test_path + '/*/*.jpg'))

X_test = np.zeros((nub_test,img_size,img_size,3),dtype=np.uint8) 
y_test = np.zeros((nub_test,),dtype=np.uint8)

i = 0
for img_path in tqdm(glob(test_path + '/*/*.jpg')):
    img = Image.open(img_path)
    img = img.resize((img_size,img_size))
    arr = np.asarray(img)
    X_test[i, :, :, :] = arr
          
    if img_path.split('/')[-2] == 'amoeba':
        # Set amoeba class as 1
        y_test[i] = 1
    else:
        # Set no amoeba class as 0
        y_test[i] = 0
        
    i += 1
# Out:
# 100%|██████████| 66/66 [00:02<00:00, 30.27it/s]

# %%
# # Visualize the training dataset
fig,axes = plt.subplots(3,4,figsize=(20, 20))

j = 0
for i,img in enumerate(X_train_full[:12]):
    axes[i//4,j%4].imshow(img)
    j+=1

# %%
# normalize the dataset
X_mean = X_train_full.mean(axis=0, keepdims=True)
X_std = X_train_full.std(axis=0, keepdims=True) + 1e-7
X_train_full_norm = (X_train_full - X_mean) / X_std
X_test_norm = (X_test - X_mean) / X_std

X_train_full_norm = X_train_full_norm[..., np.newaxis]
X_test_norm = X_test_norm[..., np.newaxis]

# %%
# Split the X_train_full_norm and y_train_full dataset randomly
def split_dataset(X_train_full_norm, y_train_full):
    # randomize X_train_full_norm and y_train_full array at the same order
    total_images = len(X_train_full_norm)
    idx = np.random.choice(np.arange(total_images), total_images, replace=False)
    X_train_full_norm = X_train_full_norm[idx]
    y_train_full = y_train_full[idx]

    # split the X_train_full into X_train and X_valid
    X_train_norm, X_validation_norm = X_train_full_norm[0 : int(total_images*5/6)], X_train_full_norm[int(total_images*5/6):total_images]
    y_train, y_validation = y_train_full[0 : int(total_images*5/6)], y_train_full[int(total_images*5/6):total_images]
    return X_train_norm, X_validation_norm, y_train, y_validation

# %% [markdown]
# # Build and train the model

# %% [markdown]
# Simple convolustional neural network (CNN) is used to train the model. It is usually composed of different layers in keras. The Layers are the basic building blocks of neural networks in Keras. Those layers are composed of and can be referred in Keras doc: convolutional layers (https://keras.io/api/layers/convolution_layers/convolution2d/), pooling layer (https://keras.io/api/layers/pooling_layers/), input and dense layer (https://keras.io/api/layers/core_layers/), flatten layer (https://keras.io/api/layers/reshaping_layers/flatten/). The layer or CNN structure can refer to example in keras doc ( https://keras.io/examples/vision/mnist_convnet/) or related books (such as •	Géron, A., 2019. Hands-on machine learning with Scikit-Learn, Keras, and TensorFlow: Concepts, tools, and techniques to build intelligent systems. " O'Reilly Media, Inc.".).

# %%
# Build the model (sequential CNN model)
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([                           
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[150, 150, 3]),  # input shape should match the input image size
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=32, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=2, activation='softmax'),
])

# %% [markdown]
# The purpose of loss functions is to compute the quantity that a model should seek to minimize during training. For more available loss function, refer keras doc: https://keras.io/api/losses/
#
# An optimizer is a function that modifies the attributes of the neural network, such as weights and learning rate. Thus, it helps in reducing the overall loss and improve the accuracy. For more available optimizer, refer keras doc: https://keras.io/api/optimizers/
#
# A metric is a function that is used to judge the performance of your model. For more available metrics, refer keras doc: https://keras.io/api/metrics/

# %%
# Compile the model
opt = keras.optimizers.Nadam(learning_rate=0.00001)  # learning rate can be changed to increase the performance of the model
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

# %% [markdown]
# Then we will start to train the model by calling `model.fit()` and save the model by calling `model.save()`. More information about these two functions are in the Keras doc: https://keras.io/api/models/.

# %%
# Train the model

# Create a dir to save our model
if not os.path.exists("model_dir"):
  os.mkdir("model_dir")

repeat_exp = 11  # Set how many times (repeat_exp - 1) you want to repeat the experiment
for i in range(1, repeat_exp): 
    # Split the dataset randomly
    X_train_norm, X_validation_norm, y_train, y_validation = split_dataset(X_train_full_norm, y_train_full)
    # Start to train the model
    print("start repeatation ", i)
    history = model.fit(X_train_norm, y_train, epochs=10, validation_data=(X_validation_norm, y_validation))
    # Save the trained model in model_dir dir
    saved_model = "model_dir/" + "model" + str(i)
    model.save(saved_model)
# Out:
# start repeatation  1
# Epoch 1/10
# 29/29 [==============================] - 21s 171ms/step - loss: 0.6829 - accuracy: 0.5229 - val_loss: 0.6156 - val_accuracy: 0.7333
# Epoch 2/10
# 29/29 [==============================] - 3s 113ms/step - loss: 0.6129 - accuracy: 0.6243 - val_loss: 0.5322 - val_accuracy: 0.8667
# Epoch 3/10
# 29/29 [==============================] - 3s 113ms/step - loss: 0.5824 - accuracy: 0.6700 - val_loss: 0.4906 - val_accuracy: 0.9278
# Epoch 4/10
# 29/29 [==============================] - 3s 113ms/step - loss: 0.5375 - accuracy: 0.7023 - val_loss: 0.4362 - val_accuracy: 0.9667
# Epoch 5/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.5284 - accuracy: 0.7202 - val_loss: 0.3976 - val_accuracy: 0.9722
# Epoch 6/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.5262 - accuracy: 0.7135 - val_loss: 0.3948 - val_accuracy: 0.9889
# Epoch 7/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.5073 - accuracy: 0.7302 - val_loss: 0.3689 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.4954 - accuracy: 0.7269 - val_loss: 0.3558 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.4625 - accuracy: 0.7547 - val_loss: 0.3280 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 3s 114ms/step - loss: 0.4606 - accuracy: 0.7681 - val_loss: 0.3565 - val_accuracy: 0.9944
# INFO:tensorflow:Assets written to: model_dir/model1/assets
# start repeatation  2
# Epoch 1/10
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4872 - accuracy: 0.7313 - val_loss: 0.3296 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 3s 115ms/step - loss: 0.4840 - accuracy: 0.7347 - val_loss: 0.3193 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 3s 116ms/step - loss: 0.4557 - accuracy: 0.7770 - val_loss: 0.2966 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 116ms/step - loss: 0.4659 - accuracy: 0.7815 - val_loss: 0.2850 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4363 - accuracy: 0.8038 - val_loss: 0.2561 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4617 - accuracy: 0.7637 - val_loss: 0.2539 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4758 - accuracy: 0.7659 - val_loss: 0.2770 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4518 - accuracy: 0.7715 - val_loss: 0.2596 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 3s 118ms/step - loss: 0.4374 - accuracy: 0.7871 - val_loss: 0.2462 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 3s 119ms/step - loss: 0.4349 - accuracy: 0.7993 - val_loss: 0.2275 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model2/assets
# start repeatation  3
# Epoch 1/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4430 - accuracy: 0.7770 - val_loss: 0.2620 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.4417 - accuracy: 0.7848 - val_loss: 0.2330 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.4286 - accuracy: 0.7793 - val_loss: 0.2315 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.4155 - accuracy: 0.7971 - val_loss: 0.2250 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4359 - accuracy: 0.7848 - val_loss: 0.2451 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.4188 - accuracy: 0.7871 - val_loss: 0.2307 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4441 - accuracy: 0.7759 - val_loss: 0.2244 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 125ms/step - loss: 0.4215 - accuracy: 0.8060 - val_loss: 0.2019 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4162 - accuracy: 0.7993 - val_loss: 0.1914 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3917 - accuracy: 0.8194 - val_loss: 0.2008 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model3/assets
# start repeatation  4
# Epoch 1/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.4036 - accuracy: 0.8038 - val_loss: 0.1845 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.4048 - accuracy: 0.8004 - val_loss: 0.1621 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.4242 - accuracy: 0.8049 - val_loss: 0.1643 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4404 - accuracy: 0.7860 - val_loss: 0.1994 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4301 - accuracy: 0.7781 - val_loss: 0.1929 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4110 - accuracy: 0.8116 - val_loss: 0.1737 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4121 - accuracy: 0.8060 - val_loss: 0.1519 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3848 - accuracy: 0.8082 - val_loss: 0.1534 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.4037 - accuracy: 0.8082 - val_loss: 0.1588 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3694 - accuracy: 0.8205 - val_loss: 0.1337 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model4/assets
# start repeatation  5
# Epoch 1/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3540 - accuracy: 0.8250 - val_loss: 0.1258 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.4020 - accuracy: 0.8161 - val_loss: 0.1626 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.3609 - accuracy: 0.8205 - val_loss: 0.1486 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3865 - accuracy: 0.8094 - val_loss: 0.1497 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3848 - accuracy: 0.8161 - val_loss: 0.1371 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3850 - accuracy: 0.8205 - val_loss: 0.1402 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.3771 - accuracy: 0.8194 - val_loss: 0.1392 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.3703 - accuracy: 0.8317 - val_loss: 0.1381 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.3498 - accuracy: 0.8417 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.3830 - accuracy: 0.8194 - val_loss: 0.1553 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model5/assets
# start repeatation  6
# Epoch 1/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3882 - accuracy: 0.8239 - val_loss: 0.1523 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3823 - accuracy: 0.8305 - val_loss: 0.1449 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3519 - accuracy: 0.8384 - val_loss: 0.1481 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3454 - accuracy: 0.8395 - val_loss: 0.1337 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3796 - accuracy: 0.8339 - val_loss: 0.1333 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3577 - accuracy: 0.8439 - val_loss: 0.1125 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3572 - accuracy: 0.8261 - val_loss: 0.1156 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3771 - accuracy: 0.8149 - val_loss: 0.1327 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3707 - accuracy: 0.8205 - val_loss: 0.1585 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3451 - accuracy: 0.8406 - val_loss: 0.1244 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model6/assets
# start repeatation  7
# Epoch 1/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.3349 - accuracy: 0.8305 - val_loss: 0.1118 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3955 - accuracy: 0.8094 - val_loss: 0.1446 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.3416 - accuracy: 0.8506 - val_loss: 0.1188 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3497 - accuracy: 0.8384 - val_loss: 0.1410 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3437 - accuracy: 0.8227 - val_loss: 0.1388 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.3473 - accuracy: 0.8406 - val_loss: 0.1332 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3402 - accuracy: 0.8562 - val_loss: 0.1316 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3486 - accuracy: 0.8328 - val_loss: 0.1230 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3270 - accuracy: 0.8640 - val_loss: 0.1536 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3293 - accuracy: 0.8540 - val_loss: 0.1254 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model7/assets
# start repeatation  8
# Epoch 1/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.3348 - accuracy: 0.8305 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3317 - accuracy: 0.8439 - val_loss: 0.0892 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3436 - accuracy: 0.8395 - val_loss: 0.0974 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3220 - accuracy: 0.8584 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3208 - accuracy: 0.8551 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3508 - accuracy: 0.8450 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3286 - accuracy: 0.8495 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3481 - accuracy: 0.8294 - val_loss: 0.0892 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3390 - accuracy: 0.8540 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3530 - accuracy: 0.8272 - val_loss: 0.1169 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model8/assets
# start repeatation  9
# Epoch 1/10
# 29/29 [==============================] - 4s 124ms/step - loss: 0.3422 - accuracy: 0.8317 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.3143 - accuracy: 0.8751 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3385 - accuracy: 0.8350 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3266 - accuracy: 0.8551 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3056 - accuracy: 0.8629 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3224 - accuracy: 0.8506 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3285 - accuracy: 0.8517 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3161 - accuracy: 0.8651 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.2860 - accuracy: 0.8629 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 121ms/step - loss: 0.3319 - accuracy: 0.8350 - val_loss: 0.0771 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model9/assets
# start repeatation  10
# Epoch 1/10
# 29/29 [==============================] - 4s 123ms/step - loss: 0.3097 - accuracy: 0.8673 - val_loss: 0.0826 - val_accuracy: 1.0000
# Epoch 2/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.2881 - accuracy: 0.8629 - val_loss: 0.0829 - val_accuracy: 1.0000
# Epoch 3/10
# 29/29 [==============================] - 3s 121ms/step - loss: 0.3162 - accuracy: 0.8562 - val_loss: 0.0741 - val_accuracy: 1.0000
# Epoch 4/10
# 29/29 [==============================] - 3s 120ms/step - loss: 0.2993 - accuracy: 0.8696 - val_loss: 0.0681 - val_accuracy: 1.0000
# Epoch 5/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3165 - accuracy: 0.8662 - val_loss: 0.0923 - val_accuracy: 1.0000
# Epoch 6/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3143 - accuracy: 0.8618 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 7/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3069 - accuracy: 0.8629 - val_loss: 0.0809 - val_accuracy: 1.0000
# Epoch 8/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3290 - accuracy: 0.8618 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 9/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.3059 - accuracy: 0.8696 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 10/10
# 29/29 [==============================] - 4s 122ms/step - loss: 0.2919 - accuracy: 0.8807 - val_loss: 0.0761 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_dir/model10/assets

# %% [markdown]
# # Evaluate the model

# %%
# visualize the model structure with model.summary(). Feel free to comment out the code below to visualize the model structure

# model.summary()

# %% [markdown]
# The test dataset is not used for training and validation, which means they are new to the trained model. And we will use it to get the performance of the model. The performance is acceptable because the accuracy for test dataset is nearly the same with accuracy for train and validation dataset.
#
# Another way to evaluate the small dataset is to repeat the experiment of evaluating the model multiple times. And we can calculate mean test accuracy.

# %%
import os   
fileList = os.listdir("./model_dir/")

test_accuracy_list = list()
loss_list = list()
for m in fileList:
    model = keras.models.load_model("./model_dir/"+m) # m='model.h5'
    results = model.evaluate(X_test_norm, y_test, batch_size=128)
    test_accuracy_list.append(results[1])
    loss_list.append(results[0])

mean_test_accuracy = np.mean(test_accuracy_list)
print("mean test accuracy: ", mean_test_accuracy)
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.2340 - accuracy: 1.0000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.1244 - accuracy: 1.0000
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0739 - accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 604 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8c52df0dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0893 - accuracy: 1.0000
# WARNING:tensorflow:6 out of the last 605 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8d305869e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 261ms/step - loss: 0.0995 - accuracy: 1.0000
# 1/1 [==============================] - 0s 248ms/step - loss: 0.1601 - accuracy: 1.0000
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1529 - accuracy: 1.0000
# 1/1 [==============================] - 0s 241ms/step - loss: 0.0983 - accuracy: 1.0000
# 1/1 [==============================] - 0s 255ms/step - loss: 0.0623 - accuracy: 1.0000
# 1/1 [==============================] - 0s 244ms/step - loss: 0.1079 - accuracy: 1.0000
# mean test accuracy:  1.0

# %% [markdown]
# Find out the best model among all trained models.

# %%
# find the best model
for a,b,c in zip(fileList, test_accuracy_list, loss_list):
    maxb = max(test_accuracy_list)
    minc = min(loss_list)
    if b == maxb and c==minc:
        model = keras.models.load_model("./model_dir/"+a)

# %% [markdown]
# At the end of epoch, the accuary for training and validation dataset should be close. This is an easy way to determine if there is overfitting or not.

# %%
# plot accuracy vs epoch
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left') 
plt.ylim([0, 1.1])
plt.show()

# %% [markdown]
# # Inference

# %% [markdown]
# We will run inference using the best model we find.
#
# We visualize the image and use your judgement to see if there is amoeba exist in the image and then compare it with the model prediction.

# %%
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np

# Visualize one image, X_test[x]. Here we choose X_test[1]. You can choose any of the images among all test dataset
inference_image_number = 1  # Choose the number from 0-66 (amount of test dataset)!
img1 = X_test[inference_image_number]
plt.imshow(img1)

# %% [markdown]
# We will predict the image above with `model.predict()` function to see if it matches with your judgement. Check the `model.predict()` reference: https://keras.io/api/models/model_training_apis/#predict-method

# %%
# class label
class_label = ['no amoeba exists', 'amoeba exists']

# image process
x = np.squeeze(X_test_norm[inference_image_number])
x = image.img_to_array(x)
x = np.expand_dims(x, axis=0)

# predict the image with model.predict()
y_prob = model.predict(x)
print("probality for each of the catogaries: ", y_prob)
y_class = y_prob.argmax(axis=-1)
print("model predict: ", class_label[y_class[0]])
# Out:
# probality for each of the catogaries:  [[0.11046647 0.8895335 ]]
# model predict:  amoeba exists
